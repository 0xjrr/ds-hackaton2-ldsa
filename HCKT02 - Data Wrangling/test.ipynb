# %%
import sqlalchemy
import pandas as pd
import requests
import bs4
import chardet
import os
import json

# %%
import zipfile
import tarfile

# %%
import bz2

# %%
# base_url= 'https://n6v6uai1jj.execute-api.eu-west-1.amazonaws.com/dev/hackathon_02/'

# x=0
# output = []
# while True:
#     f_url= base_url + str(x)
#     response = requests.get(f_url)
#     if response.status_code != 200:
#         break
#     output.append(response.json())

# %%
data_api = pd.read_csv('data/api.csv')

# %%
data_web = pd.read_csv('data/web.csv')

# %%
data_web.columns = data_web.columns.str.lower()

# %%
with  bz2.open('data/data_3.json') as x:
    data_3 = x.read()
    data = json.loads(data_3)
    data_3 = pd.DataFrame(data)

# %%
username = 'ldsa_student'
password = 'R4Fr4P3aAgMYBqqP'  # the password is not XXX by the way
host_name = 'batch4-s02-db-instance.ctq2kxc7kx1i.eu-west-1.rds.amazonaws.com'
port = 5432
db_name = 's02_db'
schema = 'public'

conn_str = 'postgresql://{}:{}@{}:{}/{}'.format(username, password, host_name, port, db_name)
conn_args = {'options': '-csearch_path={}'.format(schema)}

# %%
engine = sqlalchemy.create_engine(conn_str, connect_args=conn_args)

# %%
query = 'SELECT * FROM pg_catalog.pg_tables WHERE schemaname = \'public\';'
pd.read_sql_query(query, engine)
# Out:
#    schemaname                tablename tableowner tablespace  hasindexes  \
# 0      public                     data   postgres       None       False
# 1      public  missing_character_names   postgres       None       False
# 2      public                    genre   postgres       None       False
# 3      public                financial   postgres       None       False
# 4      public                 location   postgres       None       False
# 5      public                     info   postgres       None       False
# 6      public             hackathon_02   postgres       None       False
# 7      public              movie_actor   postgres       None       False
# 8      public                    oscar   postgres       None       False
# 9      public                    movie   postgres       None       False
# 10     public                    stock   postgres       None       False
# 11     public                    actor   postgres       None       False
# ...

# %%
query = 'SELECT * FROM hackathon_02 ;'
data_db =  pd.read_sql_query(query, engine)

# %%
response = requests.get('https://n6v6uai1jj.execute-api.eu-west-1.amazonaws.com/dev')

# %%
with open('data/data_0.tsv', 'rb') as f:
    file_data = f.read()
    encoding = chardet.detect(file_data)

# %%
data_1 = pd.read_csv(os.path.join('data', 'data_1.csv'))

# %%
data_1.columns = data_1.columns.str.lower()

# %%
data_1['timestamp'] = pd.to_datetime(data_1['timestamp']).map(pd.Timestamp.timestamp).astype('int').astype(str)

# %%
data_2 = pd.read_csv(os.path.join('data', 'data_2.csv'))

# %%
data_2['timestamp'] = data_2['timestamp'].astype('str')

# %%
data_db.columns = data_db.columns.str.lower()

# %%
data_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19616 entries, 0 to 19615
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  19616 non-null  int64
#  1   ma10       19607 non-null  float64
#  2   rsi30      19586 non-null  float64
#  3   rsi10      19606 non-null  float64
#  4   %k10       18950 non-null  float64
# dtypes: float64(4), int64(1)
# memory usage: 766.4 KB

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124999 entries, 0 to 124998
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   unnamed: 0         124999 non-null  int64
#  1   timestamp          124999 non-null  object
#  2   open               3104 non-null    float64
#  3   high               3104 non-null    float64
#  4   low                3104 non-null    float64
#  5   close              3104 non-null    float64
#  6   volume_(btc)       3104 non-null    float64
#  7   volume_(currency)  3104 non-null    float64
#  8   weighted_price     3104 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 8.6+ MB

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124999 entries, 0 to 124998
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         124999 non-null  int64
#  1   timestamp          124999 non-null  object
#  2   open               8846 non-null    float64
#  3   high               8846 non-null    float64
#  4   low                8846 non-null    float64
#  5   close              8846 non-null    float64
#  6   volume_(btc)       8846 non-null    float64
#  7   volume_(currency)  8846 non-null    float64
#  8   weighted_price     8846 non-null    float64
#  9   volumn_square      8846 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 9.5+ MB

# %%
data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124999 entries, 0 to 124998
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Timestamp          124999 non-null  int64
#  1   Open               11035 non-null   float64
#  2   High               11035 non-null   float64
#  3   Low                11035 non-null   float64
#  4   Close              11035 non-null   float64
#  5   Volume_(BTC)       11035 non-null   float64
#  6   Volume_(Currency)  11035 non-null   float64
#  7   Weighted_Price     11035 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 8.6+ MB

# %%
data_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19616 entries, 0 to 19615
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  19616 non-null  int64
#  1   ma10       19607 non-null  float64
#  2   rsi30      19586 non-null  float64
#  3   rsi10      19606 non-null  float64
#  4   %k10       18950 non-null  float64
# dtypes: float64(4), int64(1)
# memory usage: 766.4 KB

# %%
data_1.columns = data_1.columns.str.lower()
data_1 = data_1.dropna()
data_1
# Out:
#         unnamed: 0   timestamp  open  high   low  close  volume_(btc)  \
# 138            138  1332826140  4.60  4.60  4.60   4.60      1.600000
# 175            175  1332828360  4.57  4.57  4.57   4.57      5.593000
# 239            239  1332832200  4.72  4.72  4.72   4.72      1.000000
# 250            250  1332832860  4.75  4.75  4.75   4.75      1.100000
# 260            260  1332833460  4.78  4.78  4.78   4.78      6.020193
# ...            ...         ...   ...   ...   ...    ...           ...
# 124821      124821  1340307120  6.64  6.64  6.64   6.64     26.930000
# 124839      124839  1340308200  6.65  6.65  6.65   6.65      1.285458
# 124846      124846  1340308620  6.64  6.64  6.64   6.64      3.025000
# 124865      124865  1340309760  6.64  6.64  6.64   6.64      1.000000
# 124901      124901  1340311920  6.65  6.65  6.65   6.65      5.673428
#
#         volume_(currency)  weighted_price
# 138              7.360000            4.60
# ...

# %%
data_2.columns = data_2.columns.str.lower()
data_2 = data_2.dropna()
data_2
# Out:
#         unnamed: 0   timestamp   open   high    low  close  volume_(btc)  \
# 5                5  1340318100   6.64   6.64   6.64   6.64      2.019841
# 245            245  1340332500   6.64   6.64   6.64   6.64     54.000000
# 257            257  1340333220   6.65   6.65   6.65   6.65      0.612030
# 381            381  1340340660   6.63   6.63   6.63   6.63     14.953557
# 439            439  1340344140   6.63   6.63   6.63   6.63      1.012382
# ...            ...         ...    ...    ...    ...    ...           ...
# 124830      124830  1347807600  11.68  11.68  11.68  11.68      4.574098
# 124893      124893  1347811380  11.56  11.56  11.56  11.56     18.000000
# 124903      124903  1347811980  11.67  11.68  11.67  11.68     17.572500
# 124959      124959  1347815340  11.62  11.62  11.62  11.62      0.199656
# 124961      124961  1347815460  11.62  11.62  11.62  11.62      0.700000
#
#         volume_(currency)  weighted_price  volumn_square
# ...

# %%
data_3.columns = data_3.columns.str.lower()
data_3 = data_3.dropna()
data_3
# Out:
#          timestamp   open   high    low  close  volume_(btc)  \
# 23      1347819120  11.62  11.62  11.62  11.62      3.943201
# 40      1347820140  11.62  11.65  11.62  11.65      3.541665
# 41      1347820200  11.69  11.69  11.69  11.69      0.558335
# 70      1347821940  11.57  11.57  11.57  11.57      3.681072
# 107     1347824160  11.56  11.56  11.56  11.56      0.870000
# ...            ...    ...    ...    ...    ...           ...
# 124942  1355314260  13.34  13.34  13.34  13.34     24.866857
# 124943  1355314320  13.33  13.33  13.33  13.33     16.881552
# 124961  1355315400  13.42  13.42  13.42  13.42      5.763040
# 124964  1355315580  13.34  13.34  13.34  13.34      1.500000
# 124967  1355315760  13.34  13.34  13.34  13.34      3.900000
#
#         volume_(currency)  weighted_price
# 23              45.820000        11.62000
# 40              41.247684        11.64641
# 41               6.526935        11.69000
# 70              42.590000        11.57000
# ...

# %%
merged_local = pd.concat([data_1, data_2, data_3], axis=0).reset_index()

# %%
merged_local.timestamp = merged_local.timestamp.astype(int)

# %%
merged_local
# Out:
#         index  unnamed: 0   timestamp   open   high    low  close  \
# 0         138       138.0  1332826140   4.60   4.60   4.60   4.60
# 1         175       175.0  1332828360   4.57   4.57   4.57   4.57
# 2         239       239.0  1332832200   4.72   4.72   4.72   4.72
# 3         250       250.0  1332832860   4.75   4.75   4.75   4.75
# 4         260       260.0  1332833460   4.78   4.78   4.78   4.78
# ...       ...         ...         ...    ...    ...    ...    ...
# 22980  124942         NaN  1355314260  13.34  13.34  13.34  13.34
# 22981  124943         NaN  1355314320  13.33  13.33  13.33  13.33
# 22982  124961         NaN  1355315400  13.42  13.42  13.42  13.42
# 22983  124964         NaN  1355315580  13.34  13.34  13.34  13.34
# 22984  124967         NaN  1355315760  13.34  13.34  13.34  13.34
#
#        volume_(btc)  volume_(currency)  weighted_price  volumn_square
# 0          1.600000           7.360000            4.60            NaN
# ...

# %%
merged_local.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22985 entries, 0 to 22984
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              22985 non-null  object
#  1   unnamed: 0         11950 non-null  float64
#  2   timestamp          22985 non-null  int64
#  3   open               22985 non-null  float64
#  4   high               22985 non-null  float64
#  5   low                22985 non-null  float64
#  6   close              22985 non-null  float64
#  7   volume_(btc)       22985 non-null  float64
#  8   volume_(currency)  22985 non-null  float64
#  9   weighted_price     22985 non-null  float64
#  10  volumn_square      8846 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 1.9+ MB

# %%
data_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19616 entries, 0 to 19615
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  19616 non-null  int64
#  1   Timestamp   19616 non-null  float64
#  2   RSI10       0 non-null      float64
#  3   %K200       0 non-null      float64
#  4   %K30        0 non-null      float64
#  5   EMA10       19607 non-null  float64
#  6   message     0 non-null      float64
# dtypes: float64(6), int64(1)
# memory usage: 1.0 MB

# %%
data_db
# Out:
#         timestamp    ma10      rsi30      rsi10        %k10
# 0      1325317920     NaN        NaN        NaN         NaN
# 1      1325346600     NaN        NaN        NaN         NaN
# 2      1325350740     NaN        NaN        NaN         NaN
# 3      1325350800     NaN        NaN        NaN         NaN
# 4      1325391360     NaN        NaN        NaN         NaN
# ...           ...     ...        ...        ...         ...
# 19611  1351989660  10.632  53.396343  57.953487  100.000000
# 19612  1351991700  10.620  41.725604  26.388609    0.000000
# 19613  1351994460  10.632  50.897150  50.923396   82.608696
# 19614  1351994760  10.638  50.464714  49.949809   78.260870
# 19615  1351995420  10.639  51.737293  52.948358   91.304348
#
# [19616 rows x 5 columns]

# %%
pd.merge(merged_local, data_db, how='left', on='timestamp').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22985 entries, 0 to 22984
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              22985 non-null  object
#  1   unnamed: 0         11950 non-null  float64
#  2   timestamp          22985 non-null  int64
#  3   open               22985 non-null  float64
#  4   high               22985 non-null  float64
#  5   low                22985 non-null  float64
#  6   close              22985 non-null  float64
#  7   volume_(btc)       22985 non-null  float64
#  8   volume_(currency)  22985 non-null  float64
#  9   weighted_price     22985 non-null  float64
#  10  volumn_square      8846 non-null   float64
#  11  ma10               18080 non-null  float64
#  12  rsi30              18080 non-null  float64
#  13  rsi10              18080 non-null  float64
#  14  %k10               17520 non-null  float64
# ...

# %%
merge_local_w_labels = pd.merge(merged_local, pd.read_csv('data/signal.csv'), how='inner', on='timestamp')

# %%
merge_local_w_labels.drop_duplicates()
# Out:
#        index  unnamed: 0   timestamp   open   high    low  close  \
# 0        138       138.0  1332826140   4.60   4.60   4.60   4.60
# 1        175       175.0  1332828360   4.57   4.57   4.57   4.57
# 2        239       239.0  1332832200   4.72   4.72   4.72   4.72
# 3        250       250.0  1332832860   4.75   4.75   4.75   4.75
# 4        260       260.0  1332833460   4.78   4.78   4.78   4.78
# ...      ...         ...         ...    ...    ...    ...    ...
# 18075  69532         NaN  1351989660  10.68  10.68  10.68  10.68
# 18076  69566         NaN  1351991700  10.64  10.64  10.45  10.45
# 18077  69612         NaN  1351994460  10.64  10.64  10.64  10.64
# 18078  69617         NaN  1351994760  10.63  10.63  10.63  10.63
# 18079  69628         NaN  1351995420  10.66  10.66  10.66  10.66
#
#        volume_(btc)  volume_(currency)  weighted_price  volumn_square  \
# 0          1.600000           7.360000        4.600000            NaN
# ...

# %%
local_and_web_w_labels = pd.merge(merge_local_w_labels, data_web.dropna(), how='inner', on='timestamp')

# %%
local_and_web_w_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18070 entries, 0 to 18069
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              18070 non-null  object
#  1   unnamed: 0_x       11921 non-null  float64
#  2   timestamp          18070 non-null  int64
#  3   open               18070 non-null  float64
#  4   high               18070 non-null  float64
#  5   low                18070 non-null  float64
#  6   close              18070 non-null  float64
#  7   volume_(btc)       18070 non-null  float64
#  8   volume_(currency)  18070 non-null  float64
#  9   weighted_price     18070 non-null  float64
#  10  volumn_square      8846 non-null   float64
#  11  Unnamed: 0         18070 non-null  int64
#  12  signal             18070 non-null  float64
#  13  unnamed: 0.1       18070 non-null  int64
#  14  unnamed: 0_y       18070 non-null  int64
# ...

# %%
local_and_web_w_labels = local_and_web_w_labels.drop(columns=[col for col in local_and_web_w_labels.columns if 'unnamed' in col.lower()])

# %%
local_and_web_w_labels = local_and_web_w_labels.drop(['volumn_square', 'index'], axis=1, errors='ignore')

# %%
local_and_web_w_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18070 entries, 0 to 18069
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   timestamp          18070 non-null  int64
#  1   open               18070 non-null  float64
#  2   high               18070 non-null  float64
#  3   low                18070 non-null  float64
#  4   close              18070 non-null  float64
#  5   volume_(btc)       18070 non-null  float64
#  6   volume_(currency)  18070 non-null  float64
#  7   weighted_price     18070 non-null  float64
#  8   signal             18070 non-null  float64
#  9   ema200             18070 non-null  float64
#  10  ma200              18070 non-null  float64
#  11  rsi200             18070 non-null  float64
#  12  %k30               18070 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 1.9 MB

# %%
local_and_web_w_labels
# Out:
#         timestamp   open   high    low  close  volume_(btc)  \
# 0      1332826140   4.60   4.60   4.60   4.60      1.600000
# 1      1332828360   4.57   4.57   4.57   4.57      5.593000
# 2      1332832200   4.72   4.72   4.72   4.72      1.000000
# 3      1332832860   4.75   4.75   4.75   4.75      1.100000
# 4      1332833460   4.78   4.78   4.78   4.78      6.020193
# ...           ...    ...    ...    ...    ...           ...
# 18065  1351994460  10.64  10.64  10.64  10.64      1.957707
# 18066  1351994760  10.63  10.63  10.63  10.63      5.200000
# 18067  1351994760  10.63  10.63  10.63  10.63      5.200000
# 18068  1351995420  10.66  10.66  10.66  10.66      0.040338
# 18069  1351995420  10.66  10.66  10.66  10.66      0.040338
#
#        volume_(currency)  weighted_price  signal     ema200     ma200  \
# 0               7.360000            4.60     0.0   4.945316   5.07855
# 1              25.560010            4.57     0.0   4.941581   5.07440
# ...

# %%
local_and_web_w_labels.to_csv('data/train.csv', index=False)
